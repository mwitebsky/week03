# %%
% matplotlib inline
from __future__ import print_function
import random

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
# from sklearn import datasets, linear_model
import statsmodels.api as sm

# %%
def polynomials(X, degree=1):
    # See also numpy.vander
    array = [X]
    y = X
    for i in range(2, int(degree + 1)):
        y = y * X
        array.append(y)
    return np.array(array).transpose()

# %%
x = np.array(range(10))
polynomials(x, 3)
# Out:
# array([[  0,   0,   0],
#        [  1,   1,   1],
#        [  2,   4,   8],
#        [  3,   9,  27],
#        [  4,  16,  64],
#        [  5,  25, 125],
#        [  6,  36, 216],
#        [  7,  49, 343],
#        [  8,  64, 512],
#        [  9,  81, 729]])

# %%
def monomials(X, degree=1):
    y = np.array(X)
    y = np.power(X, degree)
    return np.array([y]).transpose()

# %%
monomials(x, 3)
# Out:
# array([[  0],
#        [  1],
#        [  8],
#        [ 27],
#        [ 64],
#        [125],
#        [216],
#        [343],
#        [512],
#        [729]])

# %%
def generate_data(func, a, b, n=100):
    data = []
    for _ in range(n):
        x = random.random() * (b - a)
        y = func(x)
        data.append((x, y))
    return list(sorted(data))

# %%
mu, sigma = 0, 0.1 # mean and standard deviation
# norm = np.random.normal(mu, sigma)

# Generate some data
f = lambda x: 4 + 5 * x - 3 * x*x + 0.1 * x * x * x + np.random.normal(mu, sigma)
data = generate_data(f, 0, 2, n=20)

# %%
data
# Out:
# [(0.03792953348400174, 4.138804647408542),
#  (0.13736308712448797, 4.7239206504558915),
#  (0.14530985331526924, 4.843638213558271),
#  (0.251794260422719, 4.988336631061177),
#  (0.4385315734291102, 5.592598954011803),
#  (0.4658333568131452, 5.631562008633063),
#  (0.5774177572584915, 5.9117716573109655),
#  (0.5949078670700552, 5.921244590320426),
#  (0.646890955719811, 6.210742825817311),
#  (0.6750306138137467, 6.185104742310684),
#  (0.7138368640495991, 6.181439505030941),
#  (0.8288300219178437, 5.917017039255386),
#  (0.8728788807939265, 6.106248356415712),
#  (0.9271936003027319, 6.132810075360457),
#  (0.975677261823299, 6.149990099759478),
#  (1.0242677238336364, 6.049197077410162),
#  (1.0961053477114864, 5.9494979546239914),
#  (1.1739862236838552, 5.881681511075862),
#  (1.273772698078464, 5.884030566016406),
#  (1.7607958046578822, 4.0677518971409325)]

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

for i in range(1, 10):
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     62.65
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.96e-07
# Time:                        10:45:59   Log-Likelihood:                -48.477
# No. Observations:                  20   AIC:                             98.95
# Df Residuals:                      19   BIC:                             99.95
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.8873      0.744      7.915      0.000         4.330     7.444
# ==============================================================================
# Omnibus:                       14.383   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.248
# Skew:                          -1.505   Prob(JB):                      0.00133
# Kurtosis:                       5.616   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 2.19
# Bias: -3.9107849226
# Variance: 6.08726337227
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.479
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     17.45
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           0.000511
# Time:                        10:45:59   Log-Likelihood:                -56.542
# No. Observations:                  20   AIC:                             115.1
# Df Residuals:                      19   BIC:                             116.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.8837      0.930      4.177      0.001         1.938     5.830
# ==============================================================================
# Omnibus:                       30.692   Durbin-Watson:                   0.182
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.639
# Skew:                          -2.561   Prob(JB):                     1.12e-13
# Kurtosis:                       9.733   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 8.66
# Bias: 0.900731156922
# Variance: 7.74938188972
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.271
# Model:                            OLS   Adj. R-squared:                  0.232
# Method:                 Least Squares   F-statistic:                     7.047
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0156
# Time:                        10:45:59   Log-Likelihood:                -59.902
# No. Observations:                  20   AIC:                             121.8
# Df Residuals:                      19   BIC:                             122.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             2.0266      0.763      2.655      0.016         0.429     3.625
# ==============================================================================
# Omnibus:                       40.855   Durbin-Watson:                   0.168
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              124.833
# Skew:                          -3.262   Prob(JB):                     7.81e-28
# Kurtosis:                      13.355   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 16.42
# Bias: 10.3799014134
# Variance: 6.03108052331
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.109
# Method:                 Least Squares   F-statistic:                     3.450
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):             0.0788
# Time:                        10:45:59   Log-Likelihood:                -61.388
# No. Observations:                  20   AIC:                             124.8
# Df Residuals:                      19   BIC:                             125.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.9538      0.514      1.857      0.079        -0.121     2.029
# ==============================================================================
# Omnibus:                       44.856   Durbin-Watson:                   0.136
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              163.043
# Skew:                          -3.561   Prob(JB):                     3.94e-36
# Kurtosis:                      15.039   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 22.09
# Bias: 18.0960693379
# Variance: 3.98515706511
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     1.985
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.175
# Time:                        10:46:00   Log-Likelihood:                -62.063
# No. Observations:                  20   AIC:                             126.1
# Df Residuals:                      19   BIC:                             127.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.4436      0.315      1.409      0.175        -0.215     1.103
# ==============================================================================
# Omnibus:                       45.373   Durbin-Watson:                   0.108
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.626
# Skew:                          -3.601   Prob(JB):                     2.42e-37
# Kurtosis:                      15.267   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 25.40
# Bias: 22.7500380126
# Variance: 2.63892734498
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     1.315
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.266
# Time:                        10:46:00   Log-Likelihood:                -62.387
# No. Observations:                  20   AIC:                             126.8
# Df Residuals:                      19   BIC:                             127.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.2125      0.185      1.147      0.266        -0.175     0.600
# ==============================================================================
# Omnibus:                       44.442   Durbin-Watson:                   0.090
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.666
# Skew:                          -3.530   Prob(JB):                     3.52e-35
# Kurtosis:                      14.856   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 27.22
# Bias: 25.3348819568
# Variance: 1.87392550602
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9774
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.335
# Time:                        10:46:00   Log-Likelihood:                -62.555
# No. Observations:                  20   AIC:                             127.1
# Df Residuals:                      19   BIC:                             128.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.1059      0.107      0.989      0.335        -0.118     0.330
# ==============================================================================
# Omnibus:                       43.164   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              145.773
# Skew:                          -3.433   Prob(JB):                     2.22e-32
# Kurtosis:                      14.304   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 28.23
# Bias: 26.779652496
# Variance: 1.44516059538
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.7937
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.384
# Time:                        10:46:01   Log-Likelihood:                -62.647
# No. Observations:                  20   AIC:                             127.3
# Df Residuals:                      19   BIC:                             128.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0547      0.061      0.891      0.384        -0.074     0.183
# ==============================================================================
# Omnibus:                       42.000   Durbin-Watson:                   0.070
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              134.779
# Skew:                          -3.347   Prob(JB):                     5.41e-30
# Kurtosis:                      13.813   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 28.82
# Bias: 27.6151809007
# Variance: 1.19806833489
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.6874
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):              0.417
# Time:                        10:46:01   Log-Likelihood:                -62.701
# No. Observations:                  20   AIC:                             127.4
# Df Residuals:                      19   BIC:                             128.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.0290      0.035      0.829      0.417        -0.044     0.102
# ==============================================================================
# Omnibus:                       41.081   Durbin-Watson:                   0.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              126.581
# Skew:                          -3.281   Prob(JB):                     3.26e-28
# Kurtosis:                      13.433   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 29.18
# Bias: 28.1167775747
# Variance: 1.05043984693

# %%
bs = []
vars = []
exps = np.arange(0, 10, 0.1)

for i in exps:
    X = monomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars, label="Variance")
ax = plt.gca()

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %%
domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])

for i in range(1, 10):
    X = polynomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    # The coefficients
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.755
# Method:                 Least Squares   F-statistic:                     62.65
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.96e-07
# Time:                        10:51:18   Log-Likelihood:                -48.477
# No. Observations:                  20   AIC:                             98.95
# Df Residuals:                      19   BIC:                             99.95
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.8873      0.744      7.915      0.000         4.330     7.444
# ==============================================================================
# Omnibus:                       14.383   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.248
# Skew:                          -1.505   Prob(JB):                      0.00133
# Kurtosis:                       5.616   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 2.19
# Bias: -3.9107849226
# Variance: 6.08726337227
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     129.4
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.08e-11
# Time:                        10:51:18   Log-Likelihood:                -35.730
# No. Observations:                  20   AIC:                             75.46
# Df Residuals:                      18   BIC:                             77.45
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            13.7636      1.225     11.236      0.000        11.190    16.337
# x2            -6.9680      1.023     -6.811      0.000        -9.117    -4.819
# ==============================================================================
# Omnibus:                        4.742   Durbin-Watson:                   0.158
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                3.646
# Skew:                           1.042   Prob(JB):                        0.162
# Kurtosis:                       2.831   Cond. No.                         6.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.70
# Bias: -3.13750467134
# Variance: 3.83072745781
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     147.3
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.31e-12
# Time:                        10:51:18   Log-Likelihood:                -30.101
# No. Observations:                  20   AIC:                             66.20
# Df Residuals:                      17   BIC:                             69.19
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            22.2585      2.554      8.716      0.000        16.871    27.646
# x2           -22.9715      4.535     -5.065      0.000       -32.539   -13.404
# x3             6.6923      1.867      3.584      0.002         2.753    10.631
# ==============================================================================
# Omnibus:                       12.051   Durbin-Watson:                   0.292
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):                9.659
# Skew:                           1.534   Prob(JB):                      0.00799
# Kurtosis:                       4.474   Cond. No.                         39.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.53
# Bias: -1.92639700924
# Variance: 2.4445148386
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.976
# Method:                 Least Squares   F-statistic:                     202.5
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.76e-13
# Time:                        10:51:19   Log-Likelihood:                -23.618
# No. Observations:                  20   AIC:                             55.24
# Df Residuals:                      16   BIC:                             59.22
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            37.0295      4.309      8.593      0.000        27.894    46.165
# x2           -73.4484     13.637     -5.386      0.000      -102.358   -44.539
# x3            57.5565     13.386      4.300      0.001        29.180    85.933
# x4           -15.3681      4.022     -3.821      0.002       -23.895    -6.841
# ==============================================================================
# Omnibus:                       21.512   Durbin-Watson:                   0.563
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               29.726
# Skew:                           1.872   Prob(JB):                     3.51e-07
# Kurtosis:                       7.653   Cond. No.                         300.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.47
# Bias: -1.0690783474
# Variance: 1.52605427352
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     241.2
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           8.96e-14
# Time:                        10:51:19   Log-Likelihood:                -19.064
# No. Observations:                  20   AIC:                             48.13
# Df Residuals:                      15   BIC:                             53.11
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            50.8249      5.879      8.646      0.000        38.295    63.355
# x2          -153.6517     29.483     -5.212      0.000      -216.493   -90.810
# x3           207.1663     52.039      3.981      0.001        96.247   318.086
# x4          -125.7287     37.664     -3.338      0.004      -206.008   -45.450
# x5            27.6852      9.412      2.942      0.010         7.624    47.746
# ==============================================================================
# Omnibus:                       29.954   Durbin-Watson:                   0.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.018
# Skew:                           2.385   Prob(JB):                     2.07e-14
# Kurtosis:                      10.271   Cond. No.                     2.14e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.14e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.45
# Bias: -0.658899125699
# Variance: 1.1011764768
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     307.0
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.93e-14
# Time:                        10:51:19   Log-Likelihood:                -14.184
# No. Observations:                  20   AIC:                             40.37
# Df Residuals:                      14   BIC:                             46.34
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            69.6545      7.936      8.777      0.000        52.633    86.676
# x2          -325.8900     62.771     -5.192      0.000      -460.520  -191.260
# x3           714.1018    175.957      4.058      0.001       336.712  1091.491
# x4          -775.8782    221.198     -3.508      0.003     -1250.301  -301.455
# x5           404.1743    127.094      3.180      0.007       131.585   676.763
# x6           -80.1737     27.016     -2.968      0.010      -138.117   -22.230
# ==============================================================================
# Omnibus:                       32.494   Durbin-Watson:                   1.283
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.055
# Skew:                           2.577   Prob(JB):                     5.04e-17
# Kurtosis:                      10.969   Cond. No.                     2.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.45
# Bias: -0.447706377656
# Variance: 0.884821141489
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     426.4
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.53e-14
# Time:                        10:51:19   Log-Likelihood:                -8.6494
# No. Observations:                  20   AIC:                             31.30
# Df Residuals:                      13   BIC:                             38.27
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            95.5747     10.436      9.158      0.000        73.029   118.121
# x2          -641.0679    113.033     -5.671      0.000      -885.262  -396.874
# x3          2004.3192    438.625      4.570      0.001      1056.727  2951.911
# x4         -3238.6498    813.286     -3.982      0.002     -4995.646 -1481.653
# x5          2797.6207    778.529      3.593      0.003      1115.712  4479.530
# x6         -1224.3688    369.706     -3.312      0.006     -2023.071  -425.667
# x7           212.4916     68.546      3.100      0.008        64.408   360.575
# ==============================================================================
# Omnibus:                       22.099   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.578
# Skew:                           1.903   Prob(JB):                     1.39e-07
# Kurtosis:                       7.838   Cond. No.                     1.77e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.77e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.44
# Bias: -0.281733209144
# Variance: 0.716468266517
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                     794.0
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.76e-15
# Time:                        10:51:20   Log-Likelihood:               -0.32104
# No. Observations:                  20   AIC:                             16.64
# Df Residuals:                      12   BIC:                             24.61
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           128.6793     11.026     11.671      0.000       104.657   152.702
# x2         -1151.8365    150.811     -7.638      0.000     -1480.426  -823.247
# x3          4790.9740    767.123      6.245      0.000      3119.556  6462.392
# x4         -1.062e+04   1950.652     -5.445      0.000     -1.49e+04 -6370.339
# x5          1.339e+04   2733.792      4.897      0.000      7429.850  1.93e+04
# x6         -9614.0684   2139.388     -4.494      0.001     -1.43e+04 -4952.743
# x7          3656.1624    873.212      4.187      0.001      1753.597  5558.728
# x8          -569.5452    144.210     -3.949      0.002      -883.752  -255.339
# ==============================================================================
# Omnibus:                        6.096   Durbin-Watson:                   2.018
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                3.625
# Skew:                           0.856   Prob(JB):                        0.163
# Kurtosis:                       4.192   Cond. No.                     1.47e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.44
# Bias: -0.132697768928
# Variance: 0.566347938147
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     1151.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.72e-15
# Time:                        10:51:20   Log-Likelihood:                 5.4329
# No. Observations:                  20   AIC:                             7.134
# Df Residuals:                      11   BIC:                             16.10
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1           150.0514     11.313     13.264      0.000       125.152   174.951
# x2         -1592.5810    191.468     -8.318      0.000     -2013.999 -1171.163
# x3          8072.7167   1272.727      6.343      0.000      5271.463  1.09e+04
# x4         -2.262e+04   4377.583     -5.167      0.000     -3.23e+04  -1.3e+04
# x5          3.779e+04   8612.415      4.388      0.001      1.88e+04  5.67e+04
# x6         -3.855e+04      1e+04     -3.842      0.003     -6.06e+04 -1.65e+04
# x7          2.351e+04   6822.026      3.446      0.005      8495.392  3.85e+04
# x8         -7857.1536   2493.982     -3.150      0.009     -1.33e+04 -2367.936
# x9          1103.7083    377.326      2.925      0.014       273.220  1934.197
# ==============================================================================
# Omnibus:                        0.838   Durbin-Watson:                   2.108
# Prob(Omnibus):                  0.658   Jarque-Bera (JB):                0.492
# Skew:                           0.374   Prob(JB):                        0.782
# Kurtosis:                       2.826   Cond. No.                     1.25e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.44
# Bias: -0.0629501930264
# Variance: 0.496393546549

# %%
bs = []
vars = []
exps = np.arange(0, 12, .1)

for i in exps:
    X = polynomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

plt.plot(exps, bs, label="Bias")
plt.plot(exps, vars, label="Variance")
ax = plt.gca()

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

plt.show()

# %%
for degree in range(1, 7):
    # Generate some data
    f = lambda x: 1 - 2 * x + 3 * x ** degree + np.random.normal(mu, sigma)
    data = generate_data(f, 0, 2, n=20)

    domain = np.array([x[0] for x in data])
    Y = np.array([x[1] for x in data])

    X = np.array([domain]).transpose()
    
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()
    
    # Compute the errors
    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    bs.append(bias)
    vars.append(var)

    # The coefficients
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
    
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.959
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     449.6
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.10e-14
# Time:                        11:03:02   Log-Likelihood:                -11.283
# No. Observations:                  20   AIC:                             24.57
# Df Residuals:                      19   BIC:                             25.56
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.8005      0.085     21.203      0.000         1.623     1.978
# ==============================================================================
# Omnibus:                        0.963   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.618   Jarque-Bera (JB):                0.816
# Skew:                           0.218   Prob(JB):                        0.665
# Kurtosis:                       2.111   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.33
# Bias: -0.509916016818
# Variance: 0.83242366203
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     265.3
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.28e-12
# Time:                        11:03:02   Log-Likelihood:                -27.971
# No. Observations:                  20   AIC:                             57.94
# Df Residuals:                      19   BIC:                             58.94
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             3.2103      0.197     16.289      0.000         2.798     3.623
# ==============================================================================
# Omnibus:                        5.812   Durbin-Watson:                   0.160
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                4.283
# Skew:                           1.132   Prob(JB):                        0.117
# Kurtosis:                       3.110   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 6.03
# Bias: 2.94187041865
# Variance: 3.07406666112
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     94.13
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           8.55e-09
# Time:                        11:03:03   Log-Likelihood:                -54.465
# No. Observations:                  20   AIC:                             110.9
# Df Residuals:                      19   BIC:                             111.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             6.4138      0.661      9.702      0.000         5.030     7.797
# ==============================================================================
# Omnibus:                        6.897   Durbin-Watson:                   0.100
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                4.961
# Skew:                           1.204   Prob(JB):                       0.0837
# Kurtosis:                       3.392   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 41.11
# Bias: 28.1239294479
# Variance: 12.9785455721
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.664
# Method:                 Least Squares   F-statistic:                     40.58
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           4.13e-06
# Time:                        11:03:03   Log-Likelihood:                -51.049
# No. Observations:                  20   AIC:                             104.1
# Df Residuals:                      19   BIC:                             105.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             5.5061      0.864      6.371      0.000         3.697     7.315
# ==============================================================================
# Omnibus:                       27.712   Durbin-Watson:                   0.337
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.984
# Skew:                           2.343   Prob(JB):                     3.81e-11
# Kurtosis:                       8.969   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 22.92
# Bias: 16.0603334711
# Variance: 6.85103431
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.609
# Model:                            OLS   Adj. R-squared:                  0.588
# Method:                 Least Squares   F-statistic:                     29.58
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.01e-05
# Time:                        11:03:03   Log-Likelihood:                -79.346
# No. Observations:                  20   AIC:                             160.7
# Df Residuals:                      19   BIC:                             161.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            13.8249      2.542      5.439      0.000         8.505    19.145
# ==============================================================================
# Omnibus:                       14.776   Durbin-Watson:                   0.155
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.118
# Skew:                           1.794   Prob(JB):                      0.00142
# Kurtosis:                       4.695   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 298.97
# Bias: 262.149637285
# Variance: 36.8151199543
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     20.24
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           0.000246
# Time:                        11:03:04   Log-Likelihood:                -96.005
# No. Observations:                  20   AIC:                             194.0
# Df Residuals:                      19   BIC:                             195.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            31.2208      6.939      4.499      0.000        16.697    45.744
# ==============================================================================
# Omnibus:                       38.695   Durbin-Watson:                   0.510
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              109.131
# Skew:                           3.090   Prob(JB):                     2.01e-24
# Kurtosis:                      12.632   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 1567.40
# Bias: 1271.13356864
# Variance: 296.255787726

# %%
import math
f = lambda x: math.sin(x) + np.random.normal(mu, sigma)
data = generate_data(f, 0, 2*3.14, n=100)

domain = np.array([x[0] for x in data])
Y = np.array([x[1] for x in data])


for i in range(1, 10):
    X = polynomials(domain, i)
    # Create linear regression object
    regr = sm.OLS(Y, X).fit()

    yhat = regr.predict(X)
    sse = np.mean((np.mean(yhat) - Y) ** 2)
    var = np.var(yhat)
    bias = sse - var - 0.01
    
    print(regr.summary())

    # The mean square error
    print("Residual sum of squares: %.2f" % sse)

    print("Bias: {bias}".format(bias=bias))
    print("Variance: {var}".format(var=var))
        
    # Plot outputs
    plt.scatter(domain, Y,  color='black')
    plt.plot(domain, regr.predict(X), color='blue', linewidth=3)

    plt.title("n = " + str(i))

    plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.162
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     19.10
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.06e-05
# Time:                        11:20:08   Log-Likelihood:                -101.17
# No. Observations:                 100   AIC:                             204.3
# Df Residuals:                      99   BIC:                             206.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1            -0.0748      0.017     -4.371      0.000        -0.109    -0.041
# ==============================================================================
# Omnibus:                      100.629   Durbin-Watson:                   0.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                8.241
# Skew:                           0.040   Prob(JB):                       0.0162
# Kurtosis:                       1.596   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.58
# Bias: 0.554622876727
# Variance: 0.0177511673764
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.434
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     37.52
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           7.97e-13
# Time:                        11:20:09   Log-Likelihood:                -81.563
# No. Observations:                 100   AIC:                             167.1
# Df Residuals:                      98   BIC:                             172.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.3266      0.060      5.426      0.000         0.207     0.446
# x2            -0.0821      0.012     -6.859      0.000        -0.106    -0.058
# ==============================================================================
# Omnibus:                       24.164   Durbin-Watson:                   0.071
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                7.256
# Skew:                          -0.362   Prob(JB):                       0.0266
# Kurtosis:                       1.896   Cond. No.                         22.2
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.54
# Bias: 0.311289577248
# Variance: 0.214931466513
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     878.5
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.77e-70
# Time:                        11:20:09   Log-Likelihood:                 56.925
# No. Observations:                 100   AIC:                            -107.8
# Df Residuals:                      97   BIC:                            -100.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.6673      0.038     43.508      0.000         1.591     1.743
# x2            -0.7949      0.019    -41.935      0.000        -0.833    -0.757
# x3             0.0848      0.002     38.087      0.000         0.080     0.089
# ==============================================================================
# Omnibus:                        0.256   Durbin-Watson:                   0.946
# Prob(Omnibus):                  0.880   Jarque-Bera (JB):                0.402
# Skew:                           0.100   Prob(JB):                        0.818
# Kurtosis:                       2.763   Cond. No.                         331.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual sum of squares: 0.53
# Bias: 0.00843629283613
# Variance: 0.509264254481
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     680.6
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.67e-69
# Time:                        11:20:09   Log-Likelihood:                 58.993
# No. Observations:                 100   AIC:                            -110.0
# Df Residuals:                      96   BIC:                            -99.57
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.5304      0.078     19.685      0.000         1.376     1.685
# x2            -0.6655      0.067     -9.948      0.000        -0.798    -0.533
# x3             0.0490      0.018      2.740      0.007         0.014     0.085
# x4             0.0030      0.001      2.014      0.047      4.29e-05     0.006
# ==============================================================================
# Omnibus:                        0.021   Durbin-Watson:                   0.985
# Prob(Omnibus):                  0.990   Jarque-Bera (JB):                0.029
# Skew:                          -0.010   Prob(JB):                        0.986
# Kurtosis:                       2.920   Cond. No.                     4.56e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: 0.00773707920113
# Variance: 0.509915423451
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     1037.
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           3.32e-81
# Time:                        11:20:10   Log-Likelihood:                 90.882
# No. Observations:                 100   AIC:                            -171.8
# Df Residuals:                      95   BIC:                            -158.7
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.6481      0.111      5.817      0.000         0.427     0.869
# x2             0.5892      0.145      4.069      0.000         0.302     0.877
# x3            -0.5329      0.065     -8.257      0.000        -0.661    -0.405
# x4             0.1118      0.012      9.422      0.000         0.088     0.135
# x5            -0.0071      0.001     -9.207      0.000        -0.009    -0.006
# ==============================================================================
# Omnibus:                        0.812   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.666   Jarque-Bera (JB):                0.497
# Skew:                          -0.163   Prob(JB):                        0.780
# Kurtosis:                       3.114   Cond. No.                     6.63e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: -0.000504848273671
# Variance: 0.518114860689
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     866.4
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           6.04e-80
# Time:                        11:20:10   Log-Likelihood:                 91.547
# No. Observations:                 100   AIC:                            -171.1
# Df Residuals:                      94   BIC:                            -155.5
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.8472      0.209      4.045      0.000         0.431     1.263
# x2             0.2113      0.366      0.577      0.566        -0.516     0.939
# x3            -0.2814      0.233     -1.207      0.231        -0.745     0.182
# x4             0.0358      0.069      0.521      0.603        -0.101     0.172
# x5             0.0036      0.010      0.373      0.710        -0.015     0.022
# x6            -0.0006      0.001     -1.122      0.265        -0.002     0.000
# ==============================================================================
# Omnibus:                        0.716   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.699   Jarque-Bera (JB):                0.578
# Skew:                          -0.186   Prob(JB):                        0.749
# Kurtosis:                       2.976   Cond. No.                     9.63e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.63e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: -0.000662927094953
# Variance: 0.518273707661
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.982
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     742.3
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           1.16e-78
# Time:                        11:20:11   Log-Likelihood:                 92.054
# No. Observations:                 100   AIC:                            -170.1
# Df Residuals:                      93   BIC:                            -151.9
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             1.1032      0.336      3.282      0.001         0.436     1.771
# x2            -0.4339      0.757     -0.573      0.568        -1.937     1.070
# x3             0.3164      0.657      0.482      0.631        -0.988     1.620
# x4            -0.2310      0.282     -0.818      0.416        -0.792     0.330
# x5             0.0653      0.064      1.019      0.311        -0.062     0.192
# x6            -0.0077      0.007     -1.049      0.297        -0.022     0.007
# x7             0.0003      0.000      0.974      0.333        -0.000     0.001
# ==============================================================================
# Omnibus:                        0.529   Durbin-Watson:                   1.885
# Prob(Omnibus):                  0.768   Jarque-Bera (JB):                0.427
# Skew:                          -0.159   Prob(JB):                        0.808
# Kurtosis:                       2.963   Cond. No.                     1.26e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: -0.000780137834021
# Variance: 0.518392002128
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     646.4
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.51e-77
# Time:                        11:20:11   Log-Likelihood:                 92.348
# No. Observations:                 100   AIC:                            -168.7
# Df Residuals:                      92   BIC:                            -147.9
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.8380      0.493      1.698      0.093        -0.142     1.818
# x2             0.4350      1.404      0.310      0.757        -2.353     3.223
# x3            -0.7457      1.587     -0.470      0.639        -3.897     2.405
# x4             0.4141      0.921      0.449      0.654        -1.416     2.244
# x5            -0.1498      0.299     -0.500      0.618        -0.744     0.445
# x6             0.0323      0.055      0.589      0.557        -0.077     0.141
# x7            -0.0036      0.005     -0.673      0.502        -0.014     0.007
# x8             0.0002      0.000      0.736      0.464        -0.000     0.001
# ==============================================================================
# Omnibus:                        0.489   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.783   Jarque-Bera (JB):                0.435
# Skew:                          -0.158   Prob(JB):                        0.805
# Kurtosis:                       2.929   Cond. No.                     1.60e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.6e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: -0.000819743776364
# Variance: 0.518430843546
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.983
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     579.8
# Date:                Wed, 12 Oct 2016   Prob (F-statistic):           2.70e-76
# Time:                        11:20:12   Log-Likelihood:                 93.330
# No. Observations:                 100   AIC:                            -168.7
# Df Residuals:                      91   BIC:                            -145.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# x1             0.1631      0.703      0.232      0.817        -1.232     1.559
# x2             3.2214      2.501      1.288      0.201        -1.746     8.189
# x3            -5.0476      3.570     -1.414      0.161       -12.139     2.044
# x4             3.7791      2.667      1.417      0.160        -1.519     9.077
# x5            -1.6463      1.153     -1.428      0.157        -3.936     0.644
# x6             0.4269      0.299      1.429      0.156        -0.166     1.020
# x7            -0.0646      0.046     -1.413      0.161        -0.155     0.026
# x8             0.0053      0.004      1.382      0.170        -0.002     0.013
# x9            -0.0002      0.000     -1.344      0.182        -0.000  8.59e-05
# ==============================================================================
# Omnibus:                        0.827   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.661   Jarque-Bera (JB):                0.568
# Skew:                          -0.182   Prob(JB):                        0.753
# Kurtosis:                       3.064   Cond. No.                     2.11e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.11e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Residual sum of squares: 0.53
# Bias: -0.000972241873532
# Variance: 0.518582457227
